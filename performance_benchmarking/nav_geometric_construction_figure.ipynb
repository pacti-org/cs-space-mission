# %%
# %matplotlib widget
from nav_projection import *
from utils import *

scenario = NAVScenarioGeometricGenerator(load_from_file="nav_geometric_state.pkl")

# %%
indices, contracts, _, compose_times, tactics = zip(*scenario.contracts)

# Generate the x values (the indices of the tuples)
indices = range(len(scenario.contracts))

variable_counts = [len(c.vars) for c in contracts]
constraint_counts = [len(c.a.terms) + len(c.g.terms) for c in contracts]

# %%
# Create a new figure and a subplot
fig, ax1 = plt.subplots()

ax1.set_title('')
# Setting x-ticks to multiples of 5
ax1.set_xticks(range(0, len(compose_times), 1))

# Plotting the times_in_seconds on the left y-axis
ax1.set_xlabel('Loop count')
ax1.set_ylabel('Time (seconds)', color='tab:red')
ax1.scatter(range(len(compose_times)), compose_times, color='tab:red', label='Execution time', marker='o')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Create a second y-axis for variable_counts and constraint_counts
ax2 = ax1.twinx()

# We already handled the x-label with ax1
ax2.set_ylabel('Counts', color='black')
ax2.scatter(range(len(variable_counts)), variable_counts, color='tab:blue', label='Variable count', marker='s')
ax2.scatter(range(len(constraint_counts)), constraint_counts, color='tab:green', label='Constraint count', marker='*')

ax2.tick_params(axis='y', labelcolor='black')

# Get the legend handles and labels for both axes
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()

# Create a single legend with all handles and labels
ax2.legend(handles1 + handles2, labels1 + labels2, loc='upper left', bbox_to_anchor=(0.0, 0.99), fontsize='small')

fig.set_size_inches(4.5,2)
fig.tight_layout()  # To ensure that the right y-label is not clipped
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig.savefig('nav-geometric-construction.pgf', format='pgf', bbox_inches='tight',pad_inches=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\opt\local\github.pacti\cs-space-mission\.venv\Lib\site-packages\matplotlib\backends\backend_pgf.py:262, in LatexManager._setup_latex_process(self, expect_reply)
#     261 try:
# --> 262     self.latex = subprocess.Popen(
#     263         [mpl.rcParams["pgf.texsystem"], "-halt-on-error"],
#     264         stdin=subprocess.PIPE, stdout=subprocess.PIPE,
#     265         encoding="utf-8", cwd=self.tmpdir)
#     266 except FileNotFoundError as err:
#
# File ~\scoop\apps\python311\current\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
# ...
