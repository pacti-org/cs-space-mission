# %%
# %matplotlib widget
from nav_projection import *
from utils import *

# %%
scenario = NAVScenarioGeometricGenerator(load_from_file="nav_geometric_state.pkl")

# %%
n = scenario.contracts[-1][0]
c = scenario.contracts[-1][1]

# %%
print(n)
# Out:
# 128

# %%
_ = show_bounds(n=n, c=c, var="trtd", title="true relative trajectory distance", text="", nth_tick=10)
# Out:
#   0%|          | 0/127 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
