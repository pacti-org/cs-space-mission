# %%
# %matplotlib widget

# %%
from nav_projection import *
from utils import *
from pacti_instrumentation.cpu_usage_plot import cpu_usage_plot

# %%
mu=0.005 
gain=(0.2, 0.3)
max_dv=10
me=(0.9, 1.1)

# %%
variables=["t", "trtd", "ttid"]

# %%
with cpu_usage_plot(max_data_points=500, finally_clear_output=True):
    ns = NAVScenario(iterations=10, mu=mu, gain=gain, max_dv=max_dv, me=me, variables=variables)
# Out:
# Output()

# %%
import matplotlib.pyplot as plt
indices, contracts, shift_times, compose_times = zip(*ns.contracts)

# Generate the x values (the indices of the tuples)
x_values = range(len(ns.contracts))

# Plot the integers
plt.plot(x_values, indices, label='Sequence', marker='o')

# Plot the floats
plt.plot(x_values, shift_times, label='Shift Time', marker='.')


plt.plot(x_values, compose_times, label='Compose Time', marker='x')

# Customize the chart
plt.xlabel('Index of Tuple')
plt.ylabel('Values')
plt.title('Scenario construction time')
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
